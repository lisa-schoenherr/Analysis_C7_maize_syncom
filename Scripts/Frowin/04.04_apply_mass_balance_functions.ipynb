# %% [markdown]
# # Apply Mass Balance Functions
# This script is by Frowin; I added Memote at the end

# %% [markdown]
# ## Imports

# %%
import cobra
from cobra.io import write_sbml_model, read_sbml_model
from cobra import Reaction, Metabolite
import os
import pandas as pd
import ast
from collections import defaultdict
import subprocess
import json

# %% [markdown]
# ## Paths

# %%
# Path to your working directory
project_dir = "/home/lisa/Dokumente/Programmierung/"

# Path to the model files
# model_path = project_dir+ "Models/01_before_mass_balance/"
model_path = project_dir+ "Models/06_carveme/"

# Path to the directory where you want to save the results
# save_path = project_dir + "Models/02_mass_balance/"
save_path = project_dir + "Models/07_mass_balanced/"

# %% [markdown]
# Import the results of the Identify_imbalanced_reactions script

# %%
imbalanced_reactions = pd.read_csv(save_path+'Imbalanced_reactions.csv', sep='\t')

# %% [markdown]
# Inspect the table of imbalanced reactions

# %%
imbalanced_reactions
# Out:
#    Unnamed: 0        Reaction  Occurences  \
# 0           0         CMCBTFL           7
# 1           1  SALCHS4FEabcpp           7
# 2           2     CMCBTFabcpp           2
# 3           3   DHBSZ3FEabcpp           3
#
#                                            Model IDs
# 0  ['AA5.xml', 'AA4.xml', 'AA6.xml', 'AA1.xml', '...
# 1  ['AA5.xml', 'AA4.xml', 'AA6.xml', 'AA1.xml', '...
# 2                             ['AA4.xml', 'AA2.xml']
# 3                  ['AA4.xml', 'AA3.xml', 'AA2.xml']

# %% [markdown]
# Create dictionary containing each imbalanced reaction as a key and the models this reaction is imbalanced in as a list

# %%
reaction_dict = {}

# Iterate through all rows of the imbalanced_reactions DataFrame
for row in imbalanced_reactions.iterrows():

    # The List of models is saved as a string in the DataFrame
    # Convert the string representation of the list into an actual list using ast.literal_eval
    reaction_dict[row[1][1]] = ast.literal_eval(row[1][3])

# Combine CMCBTFabcpp and CMCBTFL into one entry since the function for these is the same
reaction_dict['CMCBTF'] = reaction_dict['CMCBTFabcpp'] + list(set(reaction_dict['CMCBTFL']) - set(reaction_dict['CMCBTFabcpp']))

# %% [markdown]
# ## Functions to fix imbalanced networks

# %%
def fix_cmcbtf(model):
        
    # Change the formula and charge of fcmcbtt_c in all models
    model.metabolites.get_by_id('fcmcbtt_c').formula = 'C33FeH48N5O13'
    model.metabolites.get_by_id('fcmcbtt_c').charge = 3
    
    # Change the charge of fcmcbtt_p and _e if they are present in the model
    if 'fcmcbtt_p' in model.metabolites:
        model.metabolites.get_by_id('fcmcbtt_p').charge = 3
    if 'fcmcbtt_e' in model.metabolites:
        model.metabolites.get_by_id('fcmcbtt_e').charge = 3

    # Subtract protons from the reactions CMCBTFR1 and CMCBTFU if they are present in the model
    if 'CMCBTFR1' in model.reactions:
        model.reactions.get_by_id('CMCBTFR1').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})
    if 'CMCBTFR2' in model.reactions:
        model.reactions.get_by_id('CMCBTFR2').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})
    if 'CMCBTFU' in model.reactions:
        model.reactions.get_by_id('CMCBTFU').subtract_metabolites({model.metabolites.get_by_id('h_c'): 1})

    return model

# %%
def fix_dhbsz3feabcpp(model):

    # Change the formula and charge of fe3dhbzs3_c
    model.metabolites.get_by_id('fe3dhbzs3_c').charge = 3
    model.metabolites.get_by_id('fe3dhbzs3_c').formula = 'C30FeH28N3O16'

    # Change the charge of fe3dhbzs3_p and _e
    if 'fe3dhbzs3_p' in model.metabolites:
        model.metabolites.get_by_id('fe3dhbzs3_p').charge = 3
        model.metabolites.get_by_id('fe3dhbzs3_e').charge = 3

    if 'feenter_c' in model.metabolites:
        model.metabolites.get_by_id('feenter_c').charge = 3

    # Subtract protons from the right side of reaction FE3DHBZS3R, FEDHBZS3R1 and FEDHBZS3R2
    if "FE3DHBZS3R" in model.reactions:
        model.reactions.get_by_id('FE3DHBZS3R').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})
    if "FEDHBZS3R1" in model.reactions:
        model.reactions.get_by_id('FEDHBZS3R1').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})
    if "FEDHBZS3R2" in model.reactions:
        model.reactions.get_by_id('FEDHBZS3R2').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})
    if "FEDHBZS3R3" in model.reactions:
        model.reactions.get_by_id('FEDHBZS3R3').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})
    if "FEENTERES" in model.reactions:
        model.reactions.get_by_id('FEENTERES').subtract_metabolites({model.metabolites.get_by_id('h_c'): -1})

    # Return the model
    return model

# %%
def fix_man6gpts(model):

    # Deleting objects 
    # This wil delete all listed reactions and due to the 'True' argument also all resulting orphan metabolites. In this case only 'man6pglyc_e'
    model.remove_reactions(['MAN6Gpts', 'EX_man6pglyc_e'], True)

    # Create objects to be added to the model

    # Metabolites:

    # Metabolite manglyc_p
    manglyc_p = Metabolite(
        'manglyc_p',
        formula='C9H15O9',
        name='2(alpha-D-Mannosyl)-D-glycerate',
        compartment='p',
        charge =-1)
    
    # Metabolite manglyc_e
    manglyc_e = Metabolite(
        'manglyc_e',
        formula='C9H15O9',
        name='2(alpha-D-Mannosyl)-D-glycerate',
        compartment='e',
        charge =-1)
    
    # Reactions:

    # Reaction MANGLYCptspp
    MANGLYCptspp = Reaction('MANGLYCptspp')
    MANGLYCptspp.name = '2-O-alpha-mannosyl-D-glycerate transport via PEP:Pyr PTS (periplasm)'
    MANGLYCptspp.subsystem = ''
    MANGLYCptspp.lower_bound = 0.0 
    MANGLYCptspp.upper_bound = 1000.0  
    MANGLYCptspp.add_metabolites({
        manglyc_p: -1,
        model.metabolites.get_by_id('pep_c'): -1,
        model.metabolites.get_by_id('man6pglyc_c'): 1,
        model.metabolites.get_by_id('pyr_c'): 1
    })

    # Reaction MANGLYCtex
    MANGLYCtex = Reaction('MANGLYCtex')
    MANGLYCtex.name = '2-O-alpha-mannosyl-D-glycerate transport via diffusion (extracellular to periplasm)'
    MANGLYCtex.subsystem = ''
    MANGLYCtex.lower_bound = -1000.0 
    MANGLYCtex.upper_bound = 1000.0
    MANGLYCtex.add_metabolites({
        manglyc_e: -1,
        manglyc_p: 1
    })  

    # Reaction EX_manglyc_e
    EX_manglyc_e = Reaction('EX_manglyc_e')
    EX_manglyc_e.name = '2(alpha-D-Mannosyl)-D-glycerate exchange'
    EX_manglyc_e.subsystem = ''
    EX_manglyc_e.lower_bound = 0.0 
    EX_manglyc_e.upper_bound = 1000.0  
    EX_manglyc_e.add_metabolites({
        manglyc_e: -1
    })

    # Add reactions to the model
    model.add_reactions([MANGLYCptspp, MANGLYCtex, EX_manglyc_e])

    # Apply changes
    model.metabolites.get_by_id('man6pglyc_c').charge = -3
    model.metabolites.get_by_id('man6p_c').charge = -2

    # Return the modified model
    return model

# %%
def fix_mcbtfabcpp(model):
    
    # Change the formula and charge of fe3mcbtt_c
    model.metabolites.get_by_id('fe3mcbtt_c').charge = 3
    model.metabolites.get_by_id('fe3mcbtt_c').formula = 'C47FeH77N5O10'

    # Change the charge of fe3mcbtt_p and _e
    model.metabolites.get_by_id('fe3mcbtt_p').charge = 3
    model.metabolites.get_by_id('fe3mcbtt_e').charge = 3

    # Subtract protons from the right side of reaction MCBTFR1
    model.reactions.get_by_id('MCBTFR1').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})

    return model

# %%
def fix_salchs4feabcpp(model):

    # Change the formula and charge of salchs4fe_c
    model.metabolites.get_by_id('salchs4fe_c').charge = 3
    model.metabolites.get_by_id('salchs4fe_c').formula = 'C42FeH46N3O25'

    # Change the charge of salchs4fe_p and _e
    if 'salchs4fe_p' in model.metabolites:
        model.metabolites.get_by_id('salchs4fe_p').charge = 3
        model.metabolites.get_by_id('salchs4fe_e').charge = 3

    # Subtract protons from the right side of reaction SALCHS4FER1, SALCHS4FER2 and SALCHS4FER3
    if "SALCHS4FER1" in model.reactions:
        model.reactions.get_by_id('SALCHS4FER1').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})
    if "SALCHS4FER2" in model.reactions:
        model.reactions.get_by_id('SALCHS4FER2').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})
    if "SALCHS4FER3" in model.reactions:
        model.reactions.get_by_id('SALCHS4FER3').subtract_metabolites({model.metabolites.get_by_id('h_c'): 2})

    return model

# %%
def fix_uaccpts(model):
    
    # Change the formula and charge of uaccg_e
    model.metabolites.get_by_id('uaccg_e').charge = 0
    model.metabolites.get_by_id('uaccg_e').formula = 'C20H29N3O19P2'

    # Change the charge of uamr_c
    model.metabolites.get_by_id('uamr_c').charge = -3

    return model

# %%
def fix_tagabc(model):
    
    # Change the formula and charge of tagur_e
    model.metabolites.get_by_id('tagur_e').formula = 'C6H10O7'

    # Change the charge of tagur_c
    model.metabolites.get_by_id('tagur_c').charge = -1

    return model

# %% [markdown]
# ## Functions to test the models for imbalanced reactions

# %%
# Creates a list of all internal reactions in the model

def internal_reactions(model):
    
    # Get all reaction_ids in the model
    model_reactions = []
    for reaction in model.reactions:
        model_reactions.append(reaction.id)

    # Filter out all exchanges from the list of reactions
    indicator_exchanges = ['EX','sink','Growth']
    internal_reactions = list(filter(lambda i: all(indicator not in i for indicator in indicator_exchanges), model_reactions))
    
    return internal_reactions

# %%
# Confirms if a single reaction is mass balanced
# This function checks if the sum of the elements in the reactants equals the sum of the elements in the products
# It returns True if the reaction is mass balanced, and False otherwise

def is_mass_balanced(reaction):

    # Create a dict to store the sum of each element in the reaction
    balance = defaultdict(int)

    # Iterate over the metabolites in the reaction 
    for metabolite, coefficient in (model.reactions.get_by_id(reaction).metabolites).items():

        # Check if the metabolite has elements
        if metabolite.elements is None or len(metabolite.elements) == 0:
            return False
        
        # Sum the elements in the balance dict using their coefficients
        for element, amount in (metabolite.elements).items():
            balance[element] += coefficient * amount

    # Returns True if all elements are balanced (in a margin of 1e-10)        
    return all(-1e-10 < amount < 1e-10 for amount in balance.values())

# %%
# This function checks all internal reactions in the model and returns a list of unbalanced reactions

def find_mass_unbalanced_reactions(model):

    # Get all internal reactions in the model
    reactions = internal_reactions(model)

    # Check each reaction for mass balance using the is_mass_balanced function
    # and return a list of unbalanced reactions
    return [rxn for rxn in reactions if not is_mass_balanced(rxn)]

# %% [markdown]
# Dictionary to collect all models that still have imbalanced reactions after the modification

# %%
# Dict to save the models with imbalanced reactions after the modification by the Functions to fix imbalanced reactions
imbalanced_models_aftermod = {}

# %% [markdown]
# ## Main
#
# If a reaction is imbalanced in a model the corresponding function will be applied to it.
# Afterwards the model gets saved as "modified_{model_id}" and a dictionary containing all modified_models as keys and their still imbalanced reactions (if existing) gets created

# %%
for m in os.listdir(model_path):
    if m.endswith(".xml"):

        print("checking", m)

        # if f'{m[:-4]}_balanced.xml' not in os.listdir(save_path):

        model = read_sbml_model(model_path + m)

        try:
            if m in reaction_dict["SALCHS4FEabcpp"]:
                model = fix_salchs4feabcpp(model)
        except KeyError:
            pass
        try:
            if m in reaction_dict["MCBTFabcpp"]:
                model = fix_mcbtfabcpp(model)
        except KeyError:
            pass
        try:
            if m in reaction_dict["CMCBTF"]:
                model = fix_cmcbtf(model)
        except KeyError:
            pass
        try:
            if m in reaction_dict["DHBSZ3FEabcpp"]:
                model = fix_dhbsz3feabcpp(model)
        except KeyError:
            pass
        try:
            if m in reaction_dict["MAN6Gpts"]:
                model = fix_man6gpts(model)
        except KeyError:
            pass
        try:
            if m in reaction_dict["UACCpts"]:
                model = fix_uaccpts(model)
        except KeyError:
            pass
        try:
            if m in reaction_dict["TAGabc"]:
                model = fix_tagabc(model)
        except KeyError:
            pass

        # Write the model
        write_sbml_model(model, save_path+f'{m[:-4]}_balanced.xml')

        # Test if the fixes worked
        imbalanced_reactions_aftermod = find_mass_unbalanced_reactions(model)
        # print(imbalanced_reactions_aftermod)
        if len(imbalanced_reactions_aftermod) != 0:
            imbalanced_models_aftermod[m] = imbalanced_reactions_aftermod
        else:
            print("all fixed")

#with open('imbalanced_reactions_roots_modified2.json', 'w') as file:
    #json.dump(imbalanced_reactions_aftermod, file)
# Out:
# checking AA5.xml
# Restricted license - for non-production use only - expires 2026-11-23
# all fixed
# checking AA4.xml
# all fixed
# checking AA6.xml
# all fixed
# checking AA1.xml
# all fixed
# checking AA3.xml
# all fixed
# checking AA7.xml
# all fixed
# checking AA2.xml
# all fixed

# %% [markdown]
# To test if there are still models with imbalanced reactions. If this outputs only {}, then all models are mass balanced.

# %%
print(imbalanced_models_aftermod)
# Out:
# {}

# %% [markdown]
# ## Memote Reports

# %%
def memote_report(model_x, model_path_x, report_filename_x):
    print(f"Running memote for {model_x}")
    subprocess.run(["memote", "report", "snapshot", "--filename", report_filename_x, model_path_x, "--solver", "cplex"])

# %%
# Run memote for each model (~1-2min PER report)
for model in (f for f in os.listdir(save_path) if f.endswith(".xml")):
    # path to one specific model
    model_path = f"{save_path}/{model}"
    # path where reports should be stored and report file name
    if "AA3" in model:
        report_filename = f"Reports/mass_balance/report_{model[:3]}_balanced.html"
    else:
        report_filename = f"Reports/mass_balance/report_{model[:3]}_balanced.html"

    memote_report(model, model_path, report_filename)
print("done")
# Out:
# Running memote for AA1_balanced.xml
# Running memote for AA1_balanced.xml
# ============================= test session starts ==============================
# platform linux -- Python 3.10.16, pytest-8.3.5, pluggy-1.5.0
# rootdir: /home/lisa
# plugins: anyio-4.9.0, typeguard-4.4.2
# collected 146 items / 1 skipped
#
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py . [  0%]
# ..FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...F....F.F...F.FF.FFFFFFFFFF..         [ 44%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py . [ 45%]
# .....F........F.FFFFFF                                                   [ 60%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_biomass.py . [ 60%]
# ........F                                                                [ 67%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py . [ 67%]
# ..FFFFF......s..FFF.FF.F.FFF                                             [ 86%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_essentiality.py s [ 87%]
#                                                                          [ 87%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_growth.py s [ 88%]
#                                                                          [ 88%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_matrix.py . [ 89%]
# ...                                                                      [ 91%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbml.py . [ 91%]
# .                                                                        [ 92%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py F [ 93%]
# FFFFFFFsF.                                                               [100%]
#
# =============================== warnings summary ===============================
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/_pytest/config/__init__.py:1277
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/_pytest/config/__init__.py:1277: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: typeguard
#     self._mark_plugins_for_rewrite(hook)
#
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_id_namespace_consistency
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_id_namespace_consistency
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/memote/support/annotation.py:279: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
#   The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
#   For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#     df["duplicate"].fillna(False, inplace=True)
#
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_id_namespace_consistency
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_id_namespace_consistency
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/memote/support/annotation.py:279: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#     df["duplicate"].fillna(False, inplace=True)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ============================
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[pubchem.compound] - AssertionError: The following 1532 metabolites (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[kegg.compound] - AssertionError: The following 509 metabolites (33.22%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[seed.compound] - AssertionError: The following 383 metabolites (25.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[inchikey] - AssertionError: The following 425 metabolites (27.74%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[inchi] - AssertionError: The following 1532 metabolites (100.00%) lack annotation fo...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[chebi] - AssertionError: The following 448 metabolites (29.24%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[hmdb] - AssertionError: The following 663 metabolites (43.28%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[reactome] - AssertionError: The following 986 metabolites (64.36%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[metanetx.chemical] - AssertionError: The following 244 metabolites (15.93%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[bigg.metabolite] - AssertionError: The following 1532 metabolites (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[biocyc] - AssertionError: The following 442 metabolites (28.85%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[rhea] - AssertionError: The following 1448 reactions (62.77%) lack annotation for r...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[kegg.reaction] - AssertionError: The following 1672 reactions (72.48%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[seed.reaction] - AssertionError: The following 1133 reactions (49.11%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[metanetx.reaction] - AssertionError: The following 770 reactions (33.38%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[bigg.reaction] - AssertionError: The following 2307 reactions (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[reactome] - AssertionError: The following 2063 reactions (89.42%) lack annotation for r...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[ec-code] - AssertionError: The following 1443 reactions (62.55%) lack annotation for e...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[brenda] - AssertionError: The following 2307 reactions (100.00%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[biocyc] - AssertionError: The following 1515 reactions (65.67%) lack annotation for b...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[refseq] - AssertionError: The following 973 genes (100.00%) lack annotation for refseq:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[uniprot] - AssertionError: The following 973 genes (100.00%) lack annotation for uniprot:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ecogene] - AssertionError: The following 973 genes (100.00%) lack annotation for ecogene:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[kegg.genes] - AssertionError: The following 973 genes (100.00%) lack annotation for kegg....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbigi] - AssertionError: The following 973 genes (100.00%) lack annotation for ncbigi:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbigene] - AssertionError: The following 973 genes (100.00%) lack annotation for ncbig...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbiprotein] - AssertionError: The following 973 genes (100.00%) lack annotation for ncbip...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ccds] - AssertionError: The following 973 genes (100.00%) lack annotation for ccds:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[hprd] - AssertionError: The following 973 genes (100.00%) lack annotation for hprd:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[asap] - AssertionError: The following 973 genes (100.00%) lack annotation for asap:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[pubchem.compound] - AssertionError: There are no metabolite annotations for the pubchem.compoun...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[inchi] - AssertionError: There are no metabolite annotations for the inchi database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[bigg.metabolite] - AssertionError: There are no metabolite annotations for the bigg.metabolite...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[rhea] - AssertionError: A total of 52 reaction annotations (2.25%) do not match the
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[bigg.reaction] - AssertionError: There are no reaction annotations for the bigg.reaction dat...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[ec-code] - AssertionError: A total of 38 reaction annotations (1.65%) do not match the
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[brenda] - AssertionError: There are no reaction annotations for the brenda database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[refseq] - AssertionError: There are no gene annotations for the refseq database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[uniprot] - AssertionError: There are no gene annotations for the uniprot database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ecogene] - AssertionError: There are no gene annotations for the ecogene database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[kegg.genes] - AssertionError: There are no gene annotations for the kegg.genes database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigi] - AssertionError: There are no gene annotations for the ncbigi database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigene] - AssertionError: There are no gene annotations for the ncbigene database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbiprotein] - AssertionError: There are no gene annotations for the ncbiprotein database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ccds] - AssertionError: There are no gene annotations for the ccds database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[hprd] - AssertionError: There are no gene annotations for the hprd database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[asap] - AssertionError: There are no gene annotations for the asap database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_gene_protein_reaction_rule_presence - AssertionError: There are a total of 360 reactions (15.60%) without GPR:   ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_transport_reaction_gpr_presence - AssertionError: There are a total of 177 transport reactions (26.62% of all
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_unique_metabolites - AssertionError: Not counting the same entities in other compartments, there...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_duplicate_metabolites_in_compartments - TypeError: sequence item 0: expected str instance, tuple found
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_reactions_with_partially_identical_annotations - AssertionError: Based on annotations there are 107 different groups of over...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_duplicate_reactions - TypeError: sequence item 0: expected str instance, tuple found
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_reactions_with_identical_genes - AssertionError: Based only on equal genes there are 264 different groups of
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_medium_metabolites - TypeError: unsupported operand type(s) for /: 'int' and 'list'
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_biomass.py::test_essential_precursors_not_in_biomass[Growth] - AssertionError: Growth lacks a total of 1 essential metabolites         (1....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM3] - AssertionError: The model can produce 'MNXM3' without requiring resources. ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM63] - AssertionError: The model can produce 'MNXM63' without requiring resources....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM51] - AssertionError: The model can produce 'MNXM51' without requiring resources....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM121] - AssertionError: The model can produce 'MNXM121' without requiring resources...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM423] - AssertionError: The model can produce 'MNXM423' without requiring resources...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM21] - AssertionError: The model can produce 'MNXM21' without requiring resources....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM89557] - RuntimeError: It was not possible to uniquely identify a single metabolite ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_reaction_charge_balance - AssertionError: A total of 445 (21.80%) reactions are charge unbalanced wit...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_blocked_reactions - AssertionError: There are 50 (2.17%) blocked reactions in         the model...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_stoichiometrically_balanced_cycles - AssertionError: There are 236 (10.23%) reactions         which participate ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_deadends - AssertionError: A total of 0 (0.00%) metabolites are not consumed by any re...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_metabolites_not_produced_with_open_bounds - AssertionError: A total of 108 (7.05%) metabolites cannot be produced in co...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_metabolites_not_consumed_with_open_bounds - AssertionError: A total of 108 (7.05%) metabolites cannot be consumed in co...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_reactions_unbounded_flux_default_condition - AssertionError:  A fraction of 44.19% of the non-blocked reactions (in tota...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolite_sbo_presence - AssertionError: A total of 0 metabolites (0.00%) lack annotation with any type
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_reaction_sbo_presence - AssertionError: A total of 0 reactions (0.00%) lack annotation with any type
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_gene_sbo_presence - AssertionError: A total of 0 genes (0.00%) lack annotation with any type of
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolic_reaction_specific_sbo_presence - AssertionError: A total of 1 metabolic reactions (0.07% of all purely
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_transport_reaction_specific_sbo_presence - AssertionError: A total of 0 metabolic reactions (0.00% of all transport
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolite_specific_sbo_presence - AssertionError: A total of 0 transport reactions (0.00% of all metabolites)
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_gene_specific_sbo_presence - AssertionError: A total of 0 genes (0.00% of all genes) lack             an...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_exchange_specific_sbo_presence - AssertionError: A total of 0 exchange reactions (0.00% of all exchange
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_sink_specific_sbo_presence - AssertionError: A total of 0 genes (0.00% of all sink reactions) lack
# ============ 79 failed, 63 passed, 5 skipped, 5 warnings in 19.05s =============
# Writing snapshot report to 'Reports/mass_balance/report_AA1_balanced.html'.
# Running memote for AA3_balanced.xml
# Running memote for AA3_balanced.xml
# ============================= test session starts ==============================
# platform linux -- Python 3.10.16, pytest-8.3.5, pluggy-1.5.0
# rootdir: /home/lisa
# plugins: anyio-4.9.0, typeguard-4.4.2
# collected 146 items / 1 skipped
#
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py . [  0%]
# ..FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...F....F.F...F.FF.FFFFFFFFFF..         [ 44%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py . [ 45%]
# .....F........F.FFFFFF                                                   [ 60%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_biomass.py . [ 60%]
# F.......F                                                                [ 67%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py . [ 67%]
# .............s...FFFFF.F.FFF                                             [ 86%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_essentiality.py s [ 87%]
#                                                                          [ 87%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_growth.py s [ 88%]
#                                                                          [ 88%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_matrix.py . [ 89%]
# ...                                                                      [ 91%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbml.py . [ 91%]
# .                                                                        [ 92%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py F [ 93%]
# FFFFFFFsF.                                                               [100%]
#
# =============================== warnings summary ===============================
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/_pytest/config/__init__.py:1277
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/_pytest/config/__init__.py:1277: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: typeguard
#     self._mark_plugins_for_rewrite(hook)
#
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_id_namespace_consistency
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_id_namespace_consistency
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/memote/support/annotation.py:279: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
#   The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
#   For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#     df["duplicate"].fillna(False, inplace=True)
#
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_id_namespace_consistency
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_id_namespace_consistency
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/memote/support/annotation.py:279: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#     df["duplicate"].fillna(False, inplace=True)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ============================
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[pubchem.compound] - AssertionError: The following 1508 metabolites (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[kegg.compound] - AssertionError: The following 535 metabolites (35.48%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[seed.compound] - AssertionError: The following 400 metabolites (26.53%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[inchikey] - AssertionError: The following 448 metabolites (29.71%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[inchi] - AssertionError: The following 1508 metabolites (100.00%) lack annotation fo...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[chebi] - AssertionError: The following 462 metabolites (30.64%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[hmdb] - AssertionError: The following 672 metabolites (44.56%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[reactome] - AssertionError: The following 989 metabolites (65.58%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[metanetx.chemical] - AssertionError: The following 236 metabolites (15.65%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[bigg.metabolite] - AssertionError: The following 1508 metabolites (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[biocyc] - AssertionError: The following 471 metabolites (31.23%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[rhea] - AssertionError: The following 1417 reactions (62.62%) lack annotation for r...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[kegg.reaction] - AssertionError: The following 1613 reactions (71.28%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[seed.reaction] - AssertionError: The following 1111 reactions (49.09%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[metanetx.reaction] - AssertionError: The following 734 reactions (32.43%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[bigg.reaction] - AssertionError: The following 2263 reactions (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[reactome] - AssertionError: The following 2027 reactions (89.57%) lack annotation for r...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[ec-code] - AssertionError: The following 1380 reactions (60.98%) lack annotation for e...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[brenda] - AssertionError: The following 2263 reactions (100.00%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[biocyc] - AssertionError: The following 1485 reactions (65.62%) lack annotation for b...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[refseq] - AssertionError: The following 964 genes (100.00%) lack annotation for refseq:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[uniprot] - AssertionError: The following 964 genes (100.00%) lack annotation for uniprot:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ecogene] - AssertionError: The following 964 genes (100.00%) lack annotation for ecogene:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[kegg.genes] - AssertionError: The following 964 genes (100.00%) lack annotation for kegg....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbigi] - AssertionError: The following 964 genes (100.00%) lack annotation for ncbigi:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbigene] - AssertionError: The following 964 genes (100.00%) lack annotation for ncbig...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbiprotein] - AssertionError: The following 964 genes (100.00%) lack annotation for ncbip...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ccds] - AssertionError: The following 964 genes (100.00%) lack annotation for ccds:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[hprd] - AssertionError: The following 964 genes (100.00%) lack annotation for hprd:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[asap] - AssertionError: The following 964 genes (100.00%) lack annotation for asap:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[pubchem.compound] - AssertionError: There are no metabolite annotations for the pubchem.compoun...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[inchi] - AssertionError: There are no metabolite annotations for the inchi database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[bigg.metabolite] - AssertionError: There are no metabolite annotations for the bigg.metabolite...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[rhea] - AssertionError: A total of 75 reaction annotations (3.31%) do not match the
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[bigg.reaction] - AssertionError: There are no reaction annotations for the bigg.reaction dat...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[ec-code] - AssertionError: A total of 38 reaction annotations (1.68%) do not match the
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[brenda] - AssertionError: There are no reaction annotations for the brenda database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[refseq] - AssertionError: There are no gene annotations for the refseq database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[uniprot] - AssertionError: There are no gene annotations for the uniprot database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ecogene] - AssertionError: There are no gene annotations for the ecogene database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[kegg.genes] - AssertionError: There are no gene annotations for the kegg.genes database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigi] - AssertionError: There are no gene annotations for the ncbigi database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigene] - AssertionError: There are no gene annotations for the ncbigene database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbiprotein] - AssertionError: There are no gene annotations for the ncbiprotein database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ccds] - AssertionError: There are no gene annotations for the ccds database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[hprd] - AssertionError: There are no gene annotations for the hprd database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[asap] - AssertionError: There are no gene annotations for the asap database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_gene_protein_reaction_rule_presence - AssertionError: There are a total of 463 reactions (20.46%) without GPR:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_transport_reaction_gpr_presence - AssertionError: There are a total of 220 transport reactions (34.98% of all
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_unique_metabolites - AssertionError: Not counting the same entities in other compartments, there...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_duplicate_metabolites_in_compartments - TypeError: sequence item 0: expected str instance, tuple found
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_reactions_with_partially_identical_annotations - AssertionError: Based on annotations there are 122 different groups of over...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_duplicate_reactions - TypeError: sequence item 0: expected str instance, tuple found
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_reactions_with_identical_genes - AssertionError: Based only on equal genes there are 220 different groups of
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_medium_metabolites - TypeError: unsupported operand type(s) for /: 'int' and 'list'
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_biomass.py::test_biomass_consistency[Growth] - AssertionError: The component molar mass of the biomass reaction Growth sum...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_biomass.py::test_essential_precursors_not_in_biomass[Growth] - AssertionError: Growth lacks a total of 1 essential metabolites         (1....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM89557] - RuntimeError: It was not possible to uniquely identify a single metabolite ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_reaction_charge_balance - AssertionError: A total of 372 (18.80%) reactions are charge unbalanced wit...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_reaction_mass_balance - AssertionError: A total of 2 (0.10%) reactions are mass unbalanced with at ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_blocked_reactions - AssertionError: There are 16 (0.71%) blocked reactions in         the model:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_stoichiometrically_balanced_cycles - AssertionError: There are 371 (16.39%) reactions         which participate ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_deadends - AssertionError: A total of 0 (0.00%) metabolites are not consumed by any re...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_metabolites_not_produced_with_open_bounds - AssertionError: A total of 151 (10.01%) metabolites cannot be produced in c...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_metabolites_not_consumed_with_open_bounds - AssertionError: A total of 151 (10.01%) metabolites cannot be consumed in c...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_reactions_unbounded_flux_default_condition - AssertionError:  A fraction of 31.87% of the non-blocked reactions (in tota...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolite_sbo_presence - AssertionError: A total of 0 metabolites (0.00%) lack annotation with any type
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_reaction_sbo_presence - AssertionError: A total of 0 reactions (0.00%) lack annotation with any type
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_gene_sbo_presence - AssertionError: A total of 0 genes (0.00%) lack annotation with any type of
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolic_reaction_specific_sbo_presence - AssertionError: A total of 1 metabolic reactions (0.07% of all purely
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_transport_reaction_specific_sbo_presence - AssertionError: A total of 0 metabolic reactions (0.00% of all transport
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolite_specific_sbo_presence - AssertionError: A total of 0 transport reactions (0.00% of all metabolites)
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_gene_specific_sbo_presence - AssertionError: A total of 0 genes (0.00% of all genes) lack             an...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_exchange_specific_sbo_presence - AssertionError: A total of 0 exchange reactions (0.00% of all exchange
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_sink_specific_sbo_presence - AssertionError: A total of 0 genes (0.00% of all sink reactions) lack
# ============ 75 failed, 67 passed, 5 skipped, 5 warnings in 19.07s =============
# Writing snapshot report to 'Reports/mass_balance/report_AA3_balanced.html'.
# Running memote for AA5_balanced.xml
# Running memote for AA5_balanced.xml
# ============================= test session starts ==============================
# platform linux -- Python 3.10.16, pytest-8.3.5, pluggy-1.5.0
# rootdir: /home/lisa
# plugins: anyio-4.9.0, typeguard-4.4.2
# collected 146 items / 1 skipped
#
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py . [  0%]
# ..FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...F....F.F...F.FF.FFFFFFFFFF..         [ 44%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py . [ 45%]
# .....F........F.FFFFFF                                                   [ 60%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_biomass.py . [ 60%]
# ........F                                                                [ 67%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py . [ 67%]
# ..FFFFFFFFFFFFFFFFF.FF.F.FFF                                             [ 86%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_essentiality.py s [ 87%]
#                                                                          [ 87%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_growth.py s [ 88%]
#                                                                          [ 88%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_matrix.py . [ 89%]
# ...                                                                      [ 91%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbml.py . [ 91%]
# .                                                                        [ 92%]
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py F [ 93%]
# FFFFFFFsF.                                                               [100%]
#
# =============================== warnings summary ===============================
# ../../miniconda3/envs/MA/lib/python3.10/site-packages/_pytest/config/__init__.py:1277
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/_pytest/config/__init__.py:1277: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: typeguard
#     self._mark_plugins_for_rewrite(hook)
#
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_id_namespace_consistency
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_id_namespace_consistency
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/memote/support/annotation.py:279: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
#   The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
#   For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#     df["duplicate"].fillna(False, inplace=True)
#
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_id_namespace_consistency
# miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_id_namespace_consistency
#   /home/lisa/miniconda3/envs/MA/lib/python3.10/site-packages/memote/support/annotation.py:279: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#     df["duplicate"].fillna(False, inplace=True)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ============================
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[pubchem.compound] - AssertionError: The following 1442 metabolites (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[kegg.compound] - AssertionError: The following 437 metabolites (30.31%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[seed.compound] - AssertionError: The following 296 metabolites (20.53%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[inchikey] - AssertionError: The following 353 metabolites (24.48%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[inchi] - AssertionError: The following 1442 metabolites (100.00%) lack annotation fo...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[chebi] - AssertionError: The following 376 metabolites (26.07%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[hmdb] - AssertionError: The following 605 metabolites (41.96%) lack annotation for ...
# ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[reactome] - AssertionError: The following 1200 metabolites (66.59%) lack annotation for...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[metanetx.chemical] - AssertionError: The following 289 metabolites (16.04%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[bigg.metabolite] - AssertionError: The following 1802 metabolites (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[biocyc] - AssertionError: The following 528 metabolites (29.30%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[rhea] - AssertionError: The following 1768 reactions (64.34%) lack annotation for r...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[kegg.reaction] - AssertionError: The following 2006 reactions (73.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[seed.reaction] - AssertionError: The following 1329 reactions (48.36%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[metanetx.reaction] - AssertionError: The following 904 reactions (32.90%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[bigg.reaction] - AssertionError: The following 2748 reactions (100.00%) lack annotation for
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[reactome] - AssertionError: The following 2486 reactions (90.47%) lack annotation for r...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[ec-code] - AssertionError: The following 1738 reactions (63.25%) lack annotation for e...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[brenda] - AssertionError: The following 2748 reactions (100.00%) lack annotation for ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[biocyc] - AssertionError: The following 1867 reactions (67.94%) lack annotation for b...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[refseq] - AssertionError: The following 1347 genes (100.00%) lack annotation for refseq:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[uniprot] - AssertionError: The following 1347 genes (100.00%) lack annotation for unip...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ecogene] - AssertionError: The following 1347 genes (100.00%) lack annotation for ecog...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[kegg.genes] - AssertionError: The following 1347 genes (100.00%) lack annotation for kegg...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbigi] - AssertionError: The following 1347 genes (100.00%) lack annotation for ncbigi:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbigene] - AssertionError: The following 1347 genes (100.00%) lack annotation for ncbi...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbiprotein] - AssertionError: The following 1347 genes (100.00%) lack annotation for ncbi...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ccds] - AssertionError: The following 1347 genes (100.00%) lack annotation for ccds:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[hprd] - AssertionError: The following 1347 genes (100.00%) lack annotation for hprd:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[asap] - AssertionError: The following 1347 genes (100.00%) lack annotation for asap:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[pubchem.compound] - AssertionError: There are no metabolite annotations for the pubchem.compoun...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[inchi] - AssertionError: There are no metabolite annotations for the inchi database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[bigg.metabolite] - AssertionError: There are no metabolite annotations for the bigg.metabolite...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[rhea] - AssertionError: A total of 79 reaction annotations (2.87%) do not match the
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[bigg.reaction] - AssertionError: There are no reaction annotations for the bigg.reaction dat...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[ec-code] - AssertionError: A total of 47 reaction annotations (1.71%) do not match the
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[brenda] - AssertionError: There are no reaction annotations for the brenda database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[refseq] - AssertionError: There are no gene annotations for the refseq database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[uniprot] - AssertionError: There are no gene annotations for the uniprot database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ecogene] - AssertionError: There are no gene annotations for the ecogene database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[kegg.genes] - AssertionError: There are no gene annotations for the kegg.genes database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigi] - AssertionError: There are no gene annotations for the ncbigi database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigene] - AssertionError: There are no gene annotations for the ncbigene database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbiprotein] - AssertionError: There are no gene annotations for the ncbiprotein database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ccds] - AssertionError: There are no gene annotations for the ccds database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[hprd] - AssertionError: There are no gene annotations for the hprd database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[asap] - AssertionError: There are no gene annotations for the asap database.
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_gene_protein_reaction_rule_presence - AssertionError: There are a total of 469 reactions (17.07%) without GPR:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_transport_reaction_gpr_presence - AssertionError: There are a total of 223 transport reactions (26.52% of all
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_duplicate_metabolites_in_compartments - TypeError: sequence item 0: expected str instance, tuple found
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_reactions_with_partially_identical_annotations - AssertionError: Based on annotations there are 165 different groups of over...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_duplicate_reactions - TypeError: sequence item 0: expected str instance, tuple found
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_reactions_with_identical_genes - AssertionError: Based only on equal genes there are 297 different groups of
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_basic.py::test_find_medium_metabolites - TypeError: unsupported operand type(s) for /: 'int' and 'list'
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_biomass.py::test_essential_precursors_not_in_biomass[Growth] - AssertionError: Growth lacks a total of 1 essential metabolites         (1....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM3] - AssertionError: The model can produce 'MNXM3' without requiring resources. ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM63] - AssertionError: The model can produce 'MNXM63' without requiring resources....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM51] - AssertionError: The model can produce 'MNXM51' without requiring resources....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM121] - AssertionError: The model can produce 'MNXM121' without requiring resources...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM423] - AssertionError: The model can produce 'MNXM423' without requiring resources...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM21] - AssertionError: The model can produce 'MNXM21' without requiring resources....
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM89557] - RuntimeError: It was not possible to uniquely identify a single metabolite ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_reaction_charge_balance - AssertionError: A total of 451 (18.50%) reactions are charge unbalanced wit...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_blocked_reactions - AssertionError: There are 61 (2.22%) blocked reactions in         the model:
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_stoichiometrically_balanced_cycles - AssertionError: There are 731 (26.60%) reactions         which participate ...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_deadends - AssertionError: A total of 0 (0.00%) metabolites are not consumed by any re...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_metabolites_not_produced_with_open_bounds - AssertionError: A total of 133 (7.38%) metabolites cannot be produced in co...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_metabolites_not_consumed_with_open_bounds - AssertionError: A total of 133 (7.38%) metabolites cannot be consumed in co...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_consistency.py::test_find_reactions_unbounded_flux_default_condition - AssertionError:  A fraction of 45.91% of the non-blocked reactions (in tota...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolite_sbo_presence - AssertionError: A total of 0 metabolites (0.00%) lack annotation with any type
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_reaction_sbo_presence - AssertionError: A total of 0 reactions (0.00%) lack annotation with any type
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_gene_sbo_presence - AssertionError: A total of 0 genes (0.00%) lack annotation with any type of
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolic_reaction_specific_sbo_presence - AssertionError: A total of 1 metabolic reactions (0.06% of all purely
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_transport_reaction_specific_sbo_presence - AssertionError: A total of 0 metabolic reactions (0.00% of all transport
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_metabolite_specific_sbo_presence - AssertionError: A total of 0 transport reactions (0.00% of all metabolites)
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_gene_specific_sbo_presence - AssertionError: A total of 0 genes (0.00% of all genes) lack             an...
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_exchange_specific_sbo_presence - AssertionError: A total of 0 exchange reactions (0.00% of all exchange
# FAILED ../../miniconda3/envs/MA/lib/python3.10/site-packages/memote/suite/tests/test_sbo.py::test_sink_specific_sbo_presence - AssertionError: A total of 0 genes (0.00% of all sink reactions) lack
# ============ 78 failed, 64 passed, 5 skipped, 5 warnings in 24.79s =============
# Writing snapshot report to 'Reports/mass_balance/report_AA6_balanced.html'.
# done
